# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Adding the magic command for matplotlib
# %matplotlib inline

# %%
# Import the requests library to use API key.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Inserting try and except blocks to allow code to run smoothly
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_descript = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_descript,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | evensk
# Processing Record 3 of Set 1 | malatya
# Processing Record 4 of Set 1 | bengkulu
# Processing Record 5 of Set 1 | biak
# Processing Record 6 of Set 1 | luganville
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | cidreira
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | severo-kurilsk
# Processing Record 12 of Set 1 | matagami
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | ajaccio
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | yulara
# Processing Record 18 of Set 1 | getulio vargas
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | sur
# Processing Record 22 of Set 1 | ostrovnoy
# Processing Record 23 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 1 | amuntai
# Processing Record 25 of Set 1 | scottsbluff
# Processing Record 26 of Set 1 | kruisfontein
# Processing Record 27 of Set 1 | zhob
# Processing Record 28 of Set 1 | kilmez
# City not found. Skipping...
# Processing Record 29 of Set 1 | maumere
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | windsor
# Processing Record 33 of Set 1 | churu
# Processing Record 34 of Set 1 | monte patria
# Processing Record 35 of Set 1 | san cristobal
# Processing Record 36 of Set 1 | krasnoselkup
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | saldanha
# Processing Record 39 of Set 1 | kitimat
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | sioux lookout
# Processing Record 45 of Set 1 | guerrero negro
# Processing Record 46 of Set 1 | stephenville
# Processing Record 47 of Set 1 | kudahuvadhoo
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | sao geraldo do araguaia
# Processing Record 1 of Set 2 | san patricio
# Processing Record 2 of Set 2 | namibe
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | aasiaat
# Processing Record 5 of Set 2 | bambous virieux
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | acari
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | edson
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | salalah
# Processing Record 12 of Set 2 | tuatapere
# Processing Record 13 of Set 2 | makokou
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | mongu
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | narsaq
# Processing Record 18 of Set 2 | itarema
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | kahului
# Processing Record 21 of Set 2 | codrington
# Processing Record 22 of Set 2 | kaeo
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | boende
# Processing Record 25 of Set 2 | makakilo city
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | nikolayevka
# Processing Record 29 of Set 2 | lebanon
# Processing Record 30 of Set 2 | walvis bay
# Processing Record 31 of Set 2 | bluff
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | tateyama
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | brandon
# Processing Record 36 of Set 2 | teguise
# Processing Record 37 of Set 2 | hare bay
# Processing Record 38 of Set 2 | issia
# Processing Record 39 of Set 2 | qaanaaq
# Processing Record 40 of Set 2 | clyde river
# Processing Record 41 of Set 2 | hokitika
# Processing Record 42 of Set 2 | polunochnoye
# Processing Record 43 of Set 2 | huarmey
# Processing Record 44 of Set 2 | katherine
# Processing Record 45 of Set 2 | tigil
# Processing Record 46 of Set 2 | adre
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | ca mau
# Processing Record 49 of Set 2 | mangrol
# Processing Record 50 of Set 2 | caravelas
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | kaitangata
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | souillac
# Processing Record 5 of Set 3 | sola
# Processing Record 6 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 3 | victoria
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | paamiut
# Processing Record 10 of Set 3 | yerbogachen
# Processing Record 11 of Set 3 | airai
# Processing Record 12 of Set 3 | mollendo
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 3 | vao
# Processing Record 17 of Set 3 | duluth
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | hambantota
# Processing Record 20 of Set 3 | karratha
# Processing Record 21 of Set 3 | lluta
# Processing Record 22 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 3 | la ronge
# Processing Record 24 of Set 3 | hangu
# Processing Record 25 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 3 | pisco
# Processing Record 28 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 3 | ishigaki
# Processing Record 30 of Set 3 | ewa beach
# Processing Record 31 of Set 3 | port-gentil
# Processing Record 32 of Set 3 | high rock
# Processing Record 33 of Set 3 | mackenzie
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | kansanshi
# Processing Record 36 of Set 3 | geraldton
# Processing Record 37 of Set 3 | devonport
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | loukhi
# Processing Record 40 of Set 3 | rocha
# Processing Record 41 of Set 3 | mungaa
# Processing Record 42 of Set 3 | tessalit
# Processing Record 43 of Set 3 | port hedland
# Processing Record 44 of Set 3 | axim
# Processing Record 45 of Set 3 | mao
# Processing Record 46 of Set 3 | ponta do sol
# Processing Record 47 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 3 | aklavik
# Processing Record 49 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 3 | port hardy
# Processing Record 1 of Set 4 | torbay
# Processing Record 2 of Set 4 | dudinka
# Processing Record 3 of Set 4 | derzhavinsk
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | klaksvik
# Processing Record 6 of Set 4 | sokoni
# Processing Record 7 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 4 | lahij
# Processing Record 9 of Set 4 | pimentel
# Processing Record 10 of Set 4 | bilibino
# Processing Record 11 of Set 4 | thompson
# Processing Record 12 of Set 4 | san pedro
# Processing Record 13 of Set 4 | mar del plata
# Processing Record 14 of Set 4 | gonbad-e qabus
# Processing Record 15 of Set 4 | ola
# Processing Record 16 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 4 | westport
# Processing Record 18 of Set 4 | vilhena
# Processing Record 19 of Set 4 | agaro
# Processing Record 20 of Set 4 | nagua
# Processing Record 21 of Set 4 | iskele
# Processing Record 22 of Set 4 | honiara
# Processing Record 23 of Set 4 | esqueda
# Processing Record 24 of Set 4 | duz
# City not found. Skipping...
# Processing Record 25 of Set 4 | huilong
# Processing Record 26 of Set 4 | neiafu
# Processing Record 27 of Set 4 | leningradskiy
# Processing Record 28 of Set 4 | juegang
# Processing Record 29 of Set 4 | susehri
# Processing Record 30 of Set 4 | westpunt
# City not found. Skipping...
# Processing Record 31 of Set 4 | pali
# Processing Record 32 of Set 4 | lebu
# Processing Record 33 of Set 4 | tasiilaq
# Processing Record 34 of Set 4 | bayir
# Processing Record 35 of Set 4 | atasu
# Processing Record 36 of Set 4 | chumikan
# Processing Record 37 of Set 4 | hami
# Processing Record 38 of Set 4 | jiblah
# Processing Record 39 of Set 4 | surt
# Processing Record 40 of Set 4 | longyearbyen
# Processing Record 41 of Set 4 | alappuzha
# Processing Record 42 of Set 4 | bitung
# Processing Record 43 of Set 4 | dingle
# Processing Record 44 of Set 4 | carbonia
# Processing Record 45 of Set 4 | itaituba
# Processing Record 46 of Set 4 | kidal
# Processing Record 47 of Set 4 | avera
# Processing Record 48 of Set 4 | carutapera
# Processing Record 49 of Set 4 | peniche
# Processing Record 50 of Set 4 | atuona
# Processing Record 1 of Set 5 | lensk
# Processing Record 2 of Set 5 | hamilton
# Processing Record 3 of Set 5 | rio grande
# Processing Record 4 of Set 5 | dreux
# Processing Record 5 of Set 5 | dukat
# Processing Record 6 of Set 5 | sao filipe
# Processing Record 7 of Set 5 | komsomolskiy
# Processing Record 8 of Set 5 | koumac
# Processing Record 9 of Set 5 | fortuna
# Processing Record 10 of Set 5 | kemijarvi
# Processing Record 11 of Set 5 | monrovia
# Processing Record 12 of Set 5 | massakory
# Processing Record 13 of Set 5 | cradock
# Processing Record 14 of Set 5 | hay river
# Processing Record 15 of Set 5 | achkhoy-martan
# Processing Record 16 of Set 5 | aykhal
# Processing Record 17 of Set 5 | manyana
# Processing Record 18 of Set 5 | zhigalovo
# Processing Record 19 of Set 5 | saint-francois
# Processing Record 20 of Set 5 | malchevskaya
# Processing Record 21 of Set 5 | flinders
# Processing Record 22 of Set 5 | kavieng
# Processing Record 23 of Set 5 | college
# Processing Record 24 of Set 5 | viedma
# Processing Record 25 of Set 5 | acoyapa
# Processing Record 26 of Set 5 | lavrentiya
# Processing Record 27 of Set 5 | daro
# Processing Record 28 of Set 5 | tautira
# Processing Record 29 of Set 5 | naze
# Processing Record 30 of Set 5 | altamira
# Processing Record 31 of Set 5 | chuy
# Processing Record 32 of Set 5 | luderitz
# Processing Record 33 of Set 5 | kosmynino
# Processing Record 34 of Set 5 | iglino
# Processing Record 35 of Set 5 | halifax
# Processing Record 36 of Set 5 | chokurdakh
# Processing Record 37 of Set 5 | huaiyin
# Processing Record 38 of Set 5 | georgetown
# Processing Record 39 of Set 5 | provideniya
# Processing Record 40 of Set 5 | lodja
# Processing Record 41 of Set 5 | chichimila
# Processing Record 42 of Set 5 | karema
# Processing Record 43 of Set 5 | anchorage
# Processing Record 44 of Set 5 | tazovskiy
# Processing Record 45 of Set 5 | charters towers
# Processing Record 46 of Set 5 | bathsheba
# Processing Record 47 of Set 5 | cherskiy
# Processing Record 48 of Set 5 | laguna
# Processing Record 49 of Set 5 | ziyang
# Processing Record 50 of Set 5 | svecha
# Processing Record 1 of Set 6 | kudymkar
# Processing Record 2 of Set 6 | pochutla
# Processing Record 3 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 4 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 6 | kupang
# Processing Record 6 of Set 6 | talnakh
# Processing Record 7 of Set 6 | avarua
# Processing Record 8 of Set 6 | saint-joseph
# Processing Record 9 of Set 6 | los llanos de aridane
# Processing Record 10 of Set 6 | khatanga
# Processing Record 11 of Set 6 | qostanay
# Processing Record 12 of Set 6 | turukhansk
# Processing Record 13 of Set 6 | baykit
# Processing Record 14 of Set 6 | pombas
# Processing Record 15 of Set 6 | marsh harbour
# Processing Record 16 of Set 6 | kushmurun
# Processing Record 17 of Set 6 | mount gambier
# Processing Record 18 of Set 6 | fairbanks
# Processing Record 19 of Set 6 | sydney mines
# Processing Record 20 of Set 6 | araouane
# Processing Record 21 of Set 6 | penzance
# Processing Record 22 of Set 6 | abha
# Processing Record 23 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 24 of Set 6 | smithers
# Processing Record 25 of Set 6 | tilichiki
# Processing Record 26 of Set 6 | coquimbo
# Processing Record 27 of Set 6 | creel
# Processing Record 28 of Set 6 | hofn
# Processing Record 29 of Set 6 | fergus falls
# Processing Record 30 of Set 6 | abalak
# Processing Record 31 of Set 6 | saint anthony
# Processing Record 32 of Set 6 | canyon
# Processing Record 33 of Set 6 | luau
# Processing Record 34 of Set 6 | general pico
# Processing Record 35 of Set 6 | kilindoni
# Processing Record 36 of Set 6 | pevek
# Processing Record 37 of Set 6 | luebo
# Processing Record 38 of Set 6 | izmit
# Processing Record 39 of Set 6 | antofagasta
# Processing Record 40 of Set 6 | dhidhdhoo
# Processing Record 41 of Set 6 | banjar
# Processing Record 42 of Set 6 | lasa
# Processing Record 43 of Set 6 | oranjestad
# Processing Record 44 of Set 6 | anaconda
# Processing Record 45 of Set 6 | sheridan
# Processing Record 46 of Set 6 | ancud
# Processing Record 47 of Set 6 | te anau
# Processing Record 48 of Set 6 | yantikovo
# Processing Record 49 of Set 6 | ganzhou
# Processing Record 50 of Set 6 | mayo
# Processing Record 1 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 7 | beringovskiy
# Processing Record 3 of Set 7 | tiznit
# Processing Record 4 of Set 7 | robertsport
# Processing Record 5 of Set 7 | margate
# Processing Record 6 of Set 7 | dong hoi
# Processing Record 7 of Set 7 | palmer
# Processing Record 8 of Set 7 | turbat
# Processing Record 9 of Set 7 | inhambane
# Processing Record 10 of Set 7 | baruun-urt
# Processing Record 11 of Set 7 | castanos
# Processing Record 12 of Set 7 | mahebourg
# Processing Record 13 of Set 7 | bayji
# Processing Record 14 of Set 7 | chkalovskoye
# Processing Record 15 of Set 7 | iracoubo
# Processing Record 16 of Set 7 | tual
# Processing Record 17 of Set 7 | cabatuan
# Processing Record 18 of Set 7 | sfantu gheorghe
# Processing Record 19 of Set 7 | leh
# Processing Record 20 of Set 7 | pemberton
# Processing Record 21 of Set 7 | isangel
# Processing Record 22 of Set 7 | ormara
# Processing Record 23 of Set 7 | north platte
# Processing Record 24 of Set 7 | russell
# Processing Record 25 of Set 7 | coria
# Processing Record 26 of Set 7 | port lincoln
# Processing Record 27 of Set 7 | mama
# Processing Record 28 of Set 7 | port hueneme
# Processing Record 29 of Set 7 | katsuura
# Processing Record 30 of Set 7 | sabha
# Processing Record 31 of Set 7 | nanakuli
# Processing Record 32 of Set 7 | dzhebariki-khaya
# Processing Record 33 of Set 7 | tongliao
# Processing Record 34 of Set 7 | calvia
# Processing Record 35 of Set 7 | lompoc
# Processing Record 36 of Set 7 | xuddur
# Processing Record 37 of Set 7 | chapais
# Processing Record 38 of Set 7 | tefe
# Processing Record 39 of Set 7 | morant bay
# Processing Record 40 of Set 7 | doha
# Processing Record 41 of Set 7 | tomatlan
# Processing Record 42 of Set 7 | prachin buri
# Processing Record 43 of Set 7 | elliot
# Processing Record 44 of Set 7 | pundri
# Processing Record 45 of Set 7 | bobo dioulasso
# Processing Record 46 of Set 7 | mooi river
# City not found. Skipping...
# Processing Record 47 of Set 7 | hovd
# Processing Record 48 of Set 7 | abnub
# Processing Record 49 of Set 7 | syasstroy
# Processing Record 50 of Set 7 | kem
# Processing Record 1 of Set 8 | riviere-au-renard
# Processing Record 2 of Set 8 | finschhafen
# Processing Record 3 of Set 8 | cayenne
# Processing Record 4 of Set 8 | grenville
# Processing Record 5 of Set 8 | ekibastuz
# Processing Record 6 of Set 8 | upernavik
# Processing Record 7 of Set 8 | tabou
# Processing Record 8 of Set 8 | coahuayana
# Processing Record 9 of Set 8 | ordzhonikidze
# Processing Record 10 of Set 8 | porto novo
# Processing Record 11 of Set 8 | husavik
# Processing Record 12 of Set 8 | montepuez
# Processing Record 13 of Set 8 | san francisco del mar
# Processing Record 14 of Set 8 | gostyn
# Processing Record 15 of Set 8 | kamenka
# Processing Record 16 of Set 8 | madimba
# Processing Record 17 of Set 8 | goderich
# Processing Record 18 of Set 8 | parvatsar
# Processing Record 19 of Set 8 | faanui
# Processing Record 20 of Set 8 | ayagoz
# Processing Record 21 of Set 8 | kodiak
# Processing Record 22 of Set 8 | miramar
# Processing Record 23 of Set 8 | vanavara
# Processing Record 24 of Set 8 | iberia
# Processing Record 25 of Set 8 | itaocara
# Processing Record 26 of Set 8 | laela
# Processing Record 27 of Set 8 | zambezi
# Processing Record 28 of Set 8 | vila franca do campo
# Processing Record 29 of Set 8 | dobric
# Processing Record 30 of Set 8 | henties bay
# Processing Record 31 of Set 8 | virginia beach
# Processing Record 32 of Set 8 | galesong
# Processing Record 33 of Set 8 | takaka
# Processing Record 34 of Set 8 | sao joao da barra
# Processing Record 35 of Set 8 | vostok
# Processing Record 36 of Set 8 | mount isa
# Processing Record 37 of Set 8 | palaikastron
# Processing Record 38 of Set 8 | langsa
# Processing Record 39 of Set 8 | austin
# Processing Record 40 of Set 8 | presidencia roque saenz pena
# Processing Record 41 of Set 8 | nhulunbuy
# Processing Record 42 of Set 8 | pilar
# Processing Record 43 of Set 8 | zabol
# Processing Record 44 of Set 8 | darnah
# Processing Record 45 of Set 8 | jojoima
# Processing Record 46 of Set 8 | troitsko-pechorsk
# Processing Record 47 of Set 8 | puli
# Processing Record 48 of Set 8 | lorengau
# Processing Record 49 of Set 8 | kavaratti
# Processing Record 50 of Set 8 | salinopolis
# Processing Record 1 of Set 9 | nouadhibou
# Processing Record 2 of Set 9 | quebec
# Processing Record 3 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 9 | rumes
# Processing Record 5 of Set 9 | saint george
# Processing Record 6 of Set 9 | aswan
# Processing Record 7 of Set 9 | cockburn town
# Processing Record 8 of Set 9 | bairiki
# Processing Record 9 of Set 9 | ambovombe
# Processing Record 10 of Set 9 | asuncion
# Processing Record 11 of Set 9 | ranong
# Processing Record 12 of Set 9 | sattahip
# Processing Record 13 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 14 of Set 9 | amahai
# Processing Record 15 of Set 9 | vardo
# Processing Record 16 of Set 9 | sangar
# Processing Record 17 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 9 | garden city
# Processing Record 19 of Set 9 | callaway
# Processing Record 20 of Set 9 | sakaiminato
# Processing Record 21 of Set 9 | gat
# Processing Record 22 of Set 9 | hasaki
# Processing Record 23 of Set 9 | ucluelet
# Processing Record 24 of Set 9 | cairns
# Processing Record 25 of Set 9 | iqaluit
# Processing Record 26 of Set 9 | sambava
# Processing Record 27 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 28 of Set 9 | harper
# Processing Record 29 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 9 | eureka
# Processing Record 31 of Set 9 | makurdi
# Processing Record 32 of Set 9 | roald
# Processing Record 33 of Set 9 | olinda
# Processing Record 34 of Set 9 | pathein
# Processing Record 35 of Set 9 | rawson
# Processing Record 36 of Set 9 | oriximina
# Processing Record 37 of Set 9 | dasuya
# Processing Record 38 of Set 9 | ribas do rio pardo
# Processing Record 39 of Set 9 | jiutai
# Processing Record 40 of Set 9 | freeport
# Processing Record 41 of Set 9 | makinsk
# Processing Record 42 of Set 9 | teotitlan
# Processing Record 43 of Set 9 | badou
# Processing Record 44 of Set 9 | poum
# Processing Record 45 of Set 9 | tahta
# Processing Record 46 of Set 9 | zhengjiatun
# Processing Record 47 of Set 9 | kloulklubed
# Processing Record 48 of Set 9 | pasighat
# Processing Record 49 of Set 9 | malanje
# Processing Record 50 of Set 9 | burns lake
# Processing Record 1 of Set 10 | birao
# Processing Record 2 of Set 10 | coihaique
# Processing Record 3 of Set 10 | pangnirtung
# Processing Record 4 of Set 10 | cotonou
# Processing Record 5 of Set 10 | punto fijo
# Processing Record 6 of Set 10 | natal
# Processing Record 7 of Set 10 | bethel
# Processing Record 8 of Set 10 | ozinki
# Processing Record 9 of Set 10 | bud
# Processing Record 10 of Set 10 | anderson
# Processing Record 11 of Set 10 | vila velha
# Processing Record 12 of Set 10 | acarau
# Processing Record 13 of Set 10 | nokaneng
# Processing Record 14 of Set 10 | moissala
# Processing Record 15 of Set 10 | phan thiet
# Processing Record 16 of Set 10 | marystown
# Processing Record 17 of Set 10 | kyaikkami
# Processing Record 18 of Set 10 | fuyu
# Processing Record 19 of Set 10 | tupsan
# Processing Record 20 of Set 10 | northam
# Processing Record 21 of Set 10 | xining
# Processing Record 22 of Set 10 | fort nelson
# Processing Record 23 of Set 10 | semporna
# Processing Record 24 of Set 10 | ilabaya
# Processing Record 25 of Set 10 | lashio
# Processing Record 26 of Set 10 | acapulco
# Processing Record 27 of Set 10 | matara
# Processing Record 28 of Set 10 | moose factory
# Processing Record 29 of Set 10 | neyyattinkara
# Processing Record 30 of Set 10 | vestmannaeyjar
# Processing Record 31 of Set 10 | esperance
# Processing Record 32 of Set 10 | aysha
# Processing Record 33 of Set 10 | mehamn
# Processing Record 34 of Set 10 | fenoarivo
# Processing Record 35 of Set 10 | nemuro
# Processing Record 36 of Set 10 | muli
# Processing Record 37 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 38 of Set 10 | tres lagoas
# Processing Record 39 of Set 10 | tres picos
# Processing Record 40 of Set 10 | oktyabrskiy
# Processing Record 41 of Set 10 | solnechnyy
# Processing Record 42 of Set 10 | stratonion
# Processing Record 43 of Set 10 | rolla
# Processing Record 44 of Set 10 | mbaiki
# Processing Record 45 of Set 10 | nome
# Processing Record 46 of Set 10 | hakkari
# Processing Record 47 of Set 10 | marsaxlokk
# Processing Record 48 of Set 10 | lagoa
# Processing Record 49 of Set 10 | qaqortoq
# Processing Record 50 of Set 10 | dublin
# Processing Record 1 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 11 | rio gallegos
# Processing Record 3 of Set 11 | egvekinot
# Processing Record 4 of Set 11 | yukon
# Processing Record 5 of Set 11 | shache
# Processing Record 6 of Set 11 | aripuana
# Processing Record 7 of Set 11 | yashkino
# Processing Record 8 of Set 11 | asosa
# Processing Record 9 of Set 11 | porangatu
# Processing Record 10 of Set 11 | pacific grove
# Processing Record 11 of Set 11 | takoradi
# Processing Record 12 of Set 11 | ures
# Processing Record 13 of Set 11 | guiren
# Processing Record 14 of Set 11 | taltal
# Processing Record 15 of Set 11 | richards bay
# Processing Record 16 of Set 11 | maraba
# Processing Record 17 of Set 11 | truro
# Processing Record 18 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 11 | foz
# Processing Record 20 of Set 11 | srednekolymsk
# Processing Record 21 of Set 11 | saint-pierre
# Processing Record 22 of Set 11 | magadan
# Processing Record 23 of Set 11 | kulhudhuffushi
# Processing Record 24 of Set 11 | brae
# Processing Record 25 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 11 | ledyard
# Processing Record 27 of Set 11 | batsfjord
# Processing Record 28 of Set 11 | malindi
# Processing Record 29 of Set 11 | berlevag
# Processing Record 30 of Set 11 | auki
# Processing Record 31 of Set 11 | emerald
# Processing Record 32 of Set 11 | linares
# Processing Record 33 of Set 11 | keti bandar
# Processing Record 34 of Set 11 | kamaishi
# Processing Record 35 of Set 11 | comodoro rivadavia
# Processing Record 36 of Set 11 | alice springs
# Processing Record 37 of Set 11 | grand gaube
# Processing Record 38 of Set 11 | la asuncion
# Processing Record 39 of Set 11 | sitka
# Processing Record 40 of Set 11 | lethem
# Processing Record 41 of Set 11 | atambua
# Processing Record 42 of Set 11 | conceicao do araguaia
# Processing Record 43 of Set 11 | abbeville
# Processing Record 44 of Set 11 | awbari
# Processing Record 45 of Set 11 | kumta
# Processing Record 46 of Set 11 | ust-kalmanka
# Processing Record 47 of Set 11 | llata
# Processing Record 48 of Set 11 | forrest city
# Processing Record 49 of Set 11 | mogadishu
# Processing Record 50 of Set 11 | zhangye
# Processing Record 1 of Set 12 | santa rosa
# Processing Record 2 of Set 12 | okha
# Processing Record 3 of Set 12 | kieta
# Processing Record 4 of Set 12 | copiapo
# Processing Record 5 of Set 12 | paveh
# Processing Record 6 of Set 12 | doctor arroyo
# Processing Record 7 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 12 | kibre mengist
# Processing Record 9 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 10 of Set 12 | suntar
# Processing Record 11 of Set 12 | kisangani
# Processing Record 12 of Set 12 | quatre cocos
# Processing Record 13 of Set 12 | kodinsk
# Processing Record 14 of Set 12 | san martin
# Processing Record 15 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 12 | tucuma
# Processing Record 17 of Set 12 | klenovyy
# Processing Record 18 of Set 12 | muros
# Processing Record 19 of Set 12 | sungairaya
# Processing Record 20 of Set 12 | nouakchott
# Processing Record 21 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 22 of Set 12 | arlit
# Processing Record 23 of Set 12 | homer
# Processing Record 24 of Set 12 | batagay
# Processing Record 25 of Set 12 | asau
# Processing Record 26 of Set 12 | oga
# Processing Record 27 of Set 12 | zhigansk
# Processing Record 28 of Set 12 | umm lajj
# Processing Record 29 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 30 of Set 12 | nizwa
# Processing Record 31 of Set 12 | nuevo laredo
# Processing Record 32 of Set 12 | bacolod
# Processing Record 33 of Set 12 | buchanan
# Processing Record 34 of Set 12 | yeehaw junction
# City not found. Skipping...
# Processing Record 35 of Set 12 | emba
# Processing Record 36 of Set 12 | choya
# Processing Record 37 of Set 12 | nelson
# Processing Record 38 of Set 12 | atikokan
# Processing Record 39 of Set 12 | bandarbeyla
# Processing Record 40 of Set 12 | bousso
# Processing Record 41 of Set 12 | podosinovets
# Processing Record 42 of Set 12 | san vicente
# Processing Record 43 of Set 12 | miri
# Processing Record 44 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 45 of Set 12 | sukhobezvodnoye
# Processing Record 46 of Set 12 | qui nhon
# Processing Record 47 of Set 12 | chimore
# Processing Record 48 of Set 12 | sladkovo
# Processing Record 49 of Set 12 | aguimes
# Processing Record 50 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 13 | gombong
# Processing Record 3 of Set 13 | buala
# Processing Record 4 of Set 13 | lata
# Processing Record 5 of Set 13 | bandundu
# Processing Record 6 of Set 13 | lockhart
# Processing Record 7 of Set 13 | talcahuano
# Processing Record 8 of Set 13 | novyy urgal
# Processing Record 9 of Set 13 | zemio
# Processing Record 10 of Set 13 | camana
# Processing Record 11 of Set 13 | berezovyy
# Processing Record 12 of Set 13 | bintulu
# Processing Record 13 of Set 13 | nanortalik
# Processing Record 14 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 13 | kishi
# Processing Record 16 of Set 13 | socorro
# Processing Record 17 of Set 13 | rudnytsya
# City not found. Skipping...
# Processing Record 18 of Set 13 | ulety
# Processing Record 19 of Set 13 | campos gerais
# Processing Record 20 of Set 13 | izhma
# Processing Record 21 of Set 13 | nantucket
# Processing Record 22 of Set 13 | gunnedah
# Processing Record 23 of Set 13 | marawi
# Processing Record 24 of Set 13 | port macquarie
# Processing Record 25 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 13 | chakulia
# Processing Record 27 of Set 13 | olafsvik
# Processing Record 28 of Set 13 | necochea
# Processing Record 29 of Set 13 | urubicha
# Processing Record 30 of Set 13 | post falls
# Processing Record 31 of Set 13 | tharad
# Processing Record 32 of Set 13 | jalu
# Processing Record 33 of Set 13 | gatbo
# Processing Record 34 of Set 13 | constantine
# Processing Record 35 of Set 13 | yarmouth
# Processing Record 36 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 13 | grindavik
# Processing Record 38 of Set 13 | yanam
# Processing Record 39 of Set 13 | marang
# Processing Record 40 of Set 13 | paciran
# Processing Record 41 of Set 13 | sassandra
# Processing Record 42 of Set 13 | whitley bay
# Processing Record 43 of Set 13 | corinto
# Processing Record 44 of Set 13 | fort collins
# Processing Record 45 of Set 13 | okandja
# City not found. Skipping...
# Processing Record 46 of Set 13 | padang
# Processing Record 47 of Set 13 | shunyi
# Processing Record 48 of Set 13 | vrnjacka banja
# Processing Record 49 of Set 13 | puerto narino
# Processing Record 50 of Set 13 | hualmay
# Processing Record 1 of Set 14 | zarubino
# Processing Record 2 of Set 14 | plastun
# Processing Record 3 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 14 | dunedin
# Processing Record 5 of Set 14 | mbanza-ngungu
# Processing Record 6 of Set 14 | hibbing
# Processing Record 7 of Set 14 | kyabe
# Processing Record 8 of Set 14 | shirakawa
# Processing Record 9 of Set 14 | kabo
# Processing Record 10 of Set 14 | sinnamary
# Processing Record 11 of Set 14 | santa isabel do rio negro
# Processing Record 12 of Set 14 | beloha
# Processing Record 13 of Set 14 | aksarka
# Processing Record 14 of Set 14 | porbandar
# Processing Record 15 of Set 14 | moerai
# Processing Record 16 of Set 14 | kununurra
# Processing Record 17 of Set 14 | constitucion
# Processing Record 18 of Set 14 | waingapu
# Processing Record 19 of Set 14 | jambi
# Processing Record 20 of Set 14 | taoudenni
# Processing Record 21 of Set 14 | victor harbor
# Processing Record 22 of Set 14 | puteyets
# Processing Record 23 of Set 14 | catuday
# Processing Record 24 of Set 14 | barre
# Processing Record 25 of Set 14 | praia da vitoria
# Processing Record 26 of Set 14 | gao
# Processing Record 27 of Set 14 | nedryhayliv
# Processing Record 28 of Set 14 | progreso
# Processing Record 29 of Set 14 | marienburg
# Processing Record 30 of Set 14 | san quintin
# Processing Record 31 of Set 14 | alta floresta
# Processing Record 32 of Set 14 | koboko
# Processing Record 33 of Set 14 | riachao do dantas
# Processing Record 34 of Set 14 | carmen
# Processing Record 35 of Set 14 | nago
# Processing Record 36 of Set 14 | ambilobe
# Processing Record 37 of Set 14 | buenaventura
# Processing Record 38 of Set 14 | mauganj
# Processing Record 39 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record 40 of Set 14 | ygatimi
# Processing Record 41 of Set 14 | phaphund
# Processing Record 42 of Set 14 | sjenica
# Processing Record 43 of Set 14 | kirovsk
# Processing Record 44 of Set 14 | poya
# Processing Record 45 of Set 14 | gondanglegi
# Processing Record 46 of Set 14 | champerico
# Processing Record 47 of Set 14 | kirkwood
# Processing Record 48 of Set 14 | kuybyshevo
# Processing Record 49 of Set 14 | lexington
# Processing Record 50 of Set 14 | turtkul
# City not found. Skipping...
# Processing Record 1 of Set 15 | cortes
# Processing Record 2 of Set 15 | dubti
# Processing Record 3 of Set 15 | manaus
# Processing Record 4 of Set 15 | asfi
# Processing Record 5 of Set 15 | krasnyy chikoy
# Processing Record 6 of Set 15 | monte alegre
# Processing Record 7 of Set 15 | nizhniy odes
# Processing Record 8 of Set 15 | port keats
# Processing Record 9 of Set 15 | sept-iles
# Processing Record 10 of Set 15 | mantua
# Processing Record 11 of Set 15 | torit
# Processing Record 12 of Set 15 | kismayo
# Processing Record 13 of Set 15 | batagay-alyta
# Processing Record 14 of Set 15 | rincon
# Processing Record 15 of Set 15 | opuwo
# Processing Record 16 of Set 15 | kalmunai
# Processing Record 17 of Set 15 | azle
# Processing Record 18 of Set 15 | pyay
# Processing Record 19 of Set 15 | nizhniy kuranakh
# Processing Record 20 of Set 15 | stromness
# Processing Record 21 of Set 15 | tammisaari
# Processing Record 22 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 24 of Set 15 | broken hill
# Processing Record 25 of Set 15 | dicabisagan
# Processing Record 26 of Set 15 | onguday
# Processing Record 27 of Set 15 | qurayyat
# Processing Record 28 of Set 15 | gimli
# Processing Record 29 of Set 15 | sarangani
# Processing Record 30 of Set 15 | haines junction
# Processing Record 31 of Set 15 | tahoua
# Processing Record 32 of Set 15 | talavera de la reina
# Processing Record 33 of Set 15 | nampula
# Processing Record 34 of Set 15 | ayolas
# Processing Record 35 of Set 15 | ararat
# Processing Record 36 of Set 15 | banda aceh
# Processing Record 37 of Set 15 | neon karlovasion
# Processing Record 38 of Set 15 | praia
# Processing Record 39 of Set 15 | madras
# Processing Record 40 of Set 15 | tacuarembo
# Processing Record 41 of Set 15 | codajas
# Processing Record 42 of Set 15 | fort frances
# Processing Record 43 of Set 15 | kijang
# Processing Record 44 of Set 15 | monterey
# Processing Record 45 of Set 15 | alekseyevskaya
# Processing Record 46 of Set 15 | portland
# Processing Record 47 of Set 15 | san jeronimo
# Processing Record 48 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 49 of Set 15 | merauke
# Processing Record 50 of Set 15 | shenzhen
# Processing Record 1 of Set 16 | stepnogorsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Getting the total number of cities with data retrived.
len(city_data)
# Out:
# 699

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia -54.8000  -68.3000     49.66        50          20
# 1        Evensk  61.9500  159.2333     11.21        82         100
# 2       Malatya  38.5000   38.0000     33.85        60           0
# 3      Bengkulu  -3.8004  102.2655     76.75        83         100
# 4          Biak  -0.9131  122.8766     79.90        76           8
# 5    Luganville -15.5333  167.1667     81.45        77         100
# 6        Hobart -42.8794  147.3294     66.11        69          20
# 7      Cidreira -30.1811  -50.2056     68.34        86           0
# 8  Punta Arenas -53.1500  -70.9167     53.71        47           0
# 9         Kapaa  22.0752 -159.3190     82.38        74          20
#
#    Wind Speed Current Description Country
# 0       26.46          few clouds      AR
# 1        5.46     overcast clouds      RU
# 2        4.61           clear sky      TR
# 3        4.09     overcast clouds      ID
# 4        1.92           clear sky      ID
# 5       10.11          light rain      VU
# 6        9.22          few clouds      AU
# 7       11.27           clear sky      BR
# 8       16.11           clear sky      CL
# 9        4.00          few clouds      US

# %%
# Rearranging column order for readability
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000  -68.3000     49.66        50          20
# 1        Evensk      RU  61.9500  159.2333     11.21        82         100
# 2       Malatya      TR  38.5000   38.0000     33.85        60           0
# 3      Bengkulu      ID  -3.8004  102.2655     76.75        83         100
# 4          Biak      ID  -0.9131  122.8766     79.90        76           8
# 5    Luganville      VU -15.5333  167.1667     81.45        77         100
# 6        Hobart      AU -42.8794  147.3294     66.11        69          20
# 7      Cidreira      BR -30.1811  -50.2056     68.34        86           0
# 8  Punta Arenas      CL -53.1500  -70.9167     53.71        47           0
# 9         Kapaa      US  22.0752 -159.3190     82.38        74          20
#
#    Wind Speed Current Description
# 0       26.46          few clouds
# 1        5.46     overcast clouds
# 2        4.61           clear sky
# 3        4.09     overcast clouds
# 4        1.92           clear sky
# 5       10.11          light rain
# 6        9.22          few clouds
# 7       11.27           clear sky
# 8       16.11           clear sky
# 9        4.00          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the WeatherPy_Database into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
